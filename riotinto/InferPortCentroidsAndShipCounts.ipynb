# %% [markdown]
# ## Objective
# This script clusters the stationary ship locations to infer port coordinates and count the number of distinct ship arrivals per day.
# The HDBSCAN algorithm was employed for clustering. As discussed previously, the clustering model was employed for each geohash  independently.
#
# The only issue with this approach is that port locations at geohash boundaries (if any) will not be inferred correctly. But this a tradeoff that must be made since it compuationally unfeasible to apply clustering on a global scale.
#
# #### Libraries used
# Pandas, hdbscan, sklearn

# %%
import pandas as pd
import numpy as np
import pygeohash as gh
from tqdm import tqdm
from IPython.display import display, HTML
import matplotlib.pyplot as plt
from geopy.distance import great_circle
from sklearn.cluster import DBSCAN
from shapely.geometry import MultiPoint
from glob import glob
import hdbscan
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
def get_centermost_point(group):
    mp = MultiPoint(group[["longitude", "latitude"]].values)
    return pd.Series({"centroid_lon": mp.centroid.x,
                      "centroid_lat": mp.centroid.y})

# %%
def get_ships_per_port(group):
    ret={}
    ret["port_lat"]=group["centroid_lat"].mean()
    ret["port_lon"]=group["centroid_lon"].mean()
    ret["number_ships"]=len(group.lrimoshipno.unique())
    return pd.Series(ret)

# %%
kms_per_radian = 6371.0088
epsilon = 10.0 / kms_per_radian


def fit_db_scan(ports):
    coords = ports[['latitude', 'longitude']].values
#     db = DBSCAN(eps=epsilon, min_samples=50, n_jobs=4,
#                 algorithm='ball_tree', metric='haversine').fit(np.radians(coords))

    db = hdbscan.HDBSCAN(
        min_cluster_size=100, metric='haversine', core_dist_n_jobs=4,
        cluster_selection_epsilon=epsilon, algorithm='prims_balltree',
        cluster_selection_method='eom').fit(np.radians(coords))
    ports["cluster_labels"] = pd.Series(db.labels_)
    ports = ports.loc[ports.cluster_labels >= 0]

    centroids = ports.groupby("cluster_labels").apply(get_centermost_point)
    centroids.reset_index(inplace=True)
    ports = ports.merge(centroids, how="left", on="cluster_labels")
    return ports

# %%
geohashes = glob("data/port_locations/*/")
for path in geohashes:
    geohash = path.split("=")[1]
    ports = pd.read_parquet(path)
    if ports.shape[0] < 100:
        continue
    ports.reset_index(drop=True, inplace=True)
    print(f"Fit HDBScan for {geohash} {ports.shape[0]} data points")
    ports = fit_db_scan(ports)
    if(ports.shape[0] > 0):
        stats = ports.groupby(["cluster_labels", "date"]
                              ).apply(get_ships_per_port).reset_index()
        
        stats.to_csv(f"data/port_counts/geohash_{geohash[:-1]}_ports.csv", index=False)

        print(
            f"generated {len(stats.cluster_labels.unique())} port counts for geohash {geohash[:-1]}")
# Out:
# Fit HDBScan for 4qt/ 104 data points
# Fit HDBScan for 66t/ 1752 data points
# generated 2 port counts for geohash 66t
# Fit HDBScan for 66v/ 5942 data points
# generated 2 port counts for geohash 66v
# Fit HDBScan for 67j/ 5401 data points
# generated 2 port counts for geohash 67j
# Fit HDBScan for 67v/ 242 data points
# Fit HDBScan for 6m6/ 18061 data points
# generated 2 port counts for geohash 6m6
# Fit HDBScan for 6pw/ 223 data points
# Fit HDBScan for 6q2/ 105 data points
# Fit HDBScan for 75b/ 40723 data points
# generated 2 port counts for geohash 75b
# Fit HDBScan for 75c/ 440 data points
# generated 3 port counts for geohash 75c
# Fit HDBScan for 75f/ 106 data points
# Fit HDBScan for 7h4/ 2620 data points
# generated 2 port counts for geohash 7h4
# Fit HDBScan for 7h5/ 156 data points
# Fit HDBScan for 7h7/ 27710 data points
# generated 2 port counts for geohash 7h7
# Fit HDBScan for 7p8/ 69855 data points
# generated 2 port counts for geohash 7p8
# Fit HDBScan for 9ep/ 5267 data points
# generated 2 port counts for geohash 9ep
# Fit HDBScan for 9ky/ 1309 data points
# generated 2 port counts for geohash 9ky
# Fit HDBScan for c1e/ 1350 data points
# generated 3 port counts for geohash c1e
# Fit HDBScan for c28/ 3959 data points
# generated 4 port counts for geohash c28
# Fit HDBScan for c2b/ 1722 data points
# generated 2 port counts for geohash c2b
# Fit HDBScan for d1m/ 288 data points
# generated 2 port counts for geohash d1m
# Fit HDBScan for d1x/ 364 data points
# Fit HDBScan for d3g/ 19609 data points
# generated 2 port counts for geohash d3g
# Fit HDBScan for d6h/ 9203 data points
# generated 2 port counts for geohash d6h
# Fit HDBScan for d6n/ 124 data points
# Fit HDBScan for d7j/ 633 data points
# generated 2 port counts for geohash d7j
# Fit HDBScan for d9c/ 383 data points
# Fit HDBScan for d9f/ 134 data points
# Fit HDBScan for d9u/ 1120 data points
# generated 2 port counts for geohash d9u
# Fit HDBScan for dj2/ 115 data points
# Fit HDBScan for dj3/ 559 data points
# generated 3 port counts for geohash dj3
# Fit HDBScan for dq9/ 2554 data points
# generated 4 port counts for geohash dq9
# Fit HDBScan for dqc/ 2578 data points
# generated 2 port counts for geohash dqc
# Fit HDBScan for e9m/ 107 data points
# Fit HDBScan for e9q/ 3003 data points
# generated 2 port counts for geohash e9q
# Fit HDBScan for e9v/ 22585 data points
# generated 2 port counts for geohash e9v
# Fit HDBScan for e9w/ 11744 data points
# generated 2 port counts for geohash e9w
# Fit HDBScan for eby/ 310 data points
# Fit HDBScan for ec0/ 2709 data points
# generated 2 port counts for geohash ec0
# Fit HDBScan for eee/ 17287 data points
# generated 2 port counts for geohash eee
# Fit HDBScan for esk/ 338 data points
# Fit HDBScan for esv/ 179 data points
# Fit HDBScan for eth/ 217 data points
# Fit HDBScan for ey7/ 636 data points
# generated 2 port counts for geohash ey7
# Fit HDBScan for ey9/ 369 data points
# Fit HDBScan for eye/ 105 data points
# Fit HDBScan for eyk/ 1119 data points
# generated 2 port counts for geohash eyk
# Fit HDBScan for eyw/ 841 data points
# generated 2 port counts for geohash eyw
# Fit HDBScan for ezd/ 329 data points
# Fit HDBScan for eze/ 1417 data points
# generated 2 port counts for geohash eze
# Fit HDBScan for ezg/ 224 data points
# Fit HDBScan for f2m/ 581 data points
# generated 2 port counts for geohash f2m
# Fit HDBScan for f2w/ 299 data points
# Fit HDBScan for f8b/ 12317 data points
# generated 2 port counts for geohash f8b
# Fit HDBScan for f8h/ 407 data points
# Fit HDBScan for gbq/ 203 data points
# Fit HDBScan for gbu/ 688 data points
# generated 2 port counts for geohash gbu
# Fit HDBScan for gc3/ 327 data points
# Fit HDBScan for gcj/ 479 data points
# generated 2 port counts for geohash gcj
# Fit HDBScan for gcu/ 564 data points
# generated 2 port counts for geohash gcu
# Fit HDBScan for gcx/ 1693 data points
# generated 2 port counts for geohash gcx
# Fit HDBScan for k3v/ 289 data points
# Fit HDBScan for k6h/ 17895 data points
# generated 2 port counts for geohash k6h
# Fit HDBScan for k9f/ 1026 data points
# Fit HDBScan for kdw/ 296 data points
# Fit HDBScan for kdy/ 5419 data points
# generated 2 port counts for geohash kdy
# Fit HDBScan for kgr/ 113 data points
# Fit HDBScan for ku3/ 1133 data points
# generated 2 port counts for geohash ku3
# Fit HDBScan for kvk/ 667 data points
# generated 2 port counts for geohash kvk
# Fit HDBScan for mk2/ 362 data points
# Fit HDBScan for q9y/ 1237 data points
# generated 2 port counts for geohash q9y
# Fit HDBScan for qqg/ 723 data points
# generated 2 port counts for geohash qqg
# Fit HDBScan for qr4/ 1091 data points
# generated 2 port counts for geohash qr4
# Fit HDBScan for qrw/ 230 data points
# Fit HDBScan for qs6/ 17465 data points
# generated 2 port counts for geohash qs6
# Fit HDBScan for qs7/ 25545 data points
# generated 3 port counts for geohash qs7
# Fit HDBScan for qsk/ 63019 data points
# generated 2 port counts for geohash qsk
# Fit HDBScan for qss/ 157 data points
# Fit HDBScan for qw9/ 242 data points
# Fit HDBScan for qx1/ 279 data points
# Fit HDBScan for qx3/ 6684 data points
# generated 2 port counts for geohash qx3
# Fit HDBScan for qx6/ 1455 data points
# generated 3 port counts for geohash qx6
# Fit HDBScan for qxd/ 869 data points
# Fit HDBScan for qxg/ 3237 data points
# generated 2 port counts for geohash qxg
# Fit HDBScan for r3g/ 1397 data points
# generated 2 port counts for geohash r3g
# Fit HDBScan for r41/ 10450 data points
# generated 2 port counts for geohash r41
# Fit HDBScan for r65/ 4747 data points
# generated 2 port counts for geohash r65
# Fit HDBScan for r6h/ 441 data points
# Fit HDBScan for r7g/ 12583 data points
# generated 2 port counts for geohash r7g
# Fit HDBScan for rch/ 622 data points
# Fit HDBScan for rk3/ 6625 data points
# generated 2 port counts for geohash rk3
# Fit HDBScan for rk4/ 36604 data points
# generated 2 port counts for geohash rk4
# Fit HDBScan for rk6/ 453 data points
# Fit HDBScan for rk9/ 311 data points
# Fit HDBScan for s0v/ 341 data points
# generated 2 port counts for geohash s0v
# Fit HDBScan for smf/ 861 data points
# generated 2 port counts for geohash smf
# Fit HDBScan for sp2/ 205 data points
# Fit HDBScan for spe/ 1773 data points
# generated 2 port counts for geohash spe
# Fit HDBScan for sq6/ 111 data points
# Fit HDBScan for srh/ 2327 data points
# generated 2 port counts for geohash srh
# Fit HDBScan for str/ 611 data points
# generated 2 port counts for geohash str
# Fit HDBScan for stt/ 1612 data points
# generated 2 port counts for geohash stt
# Fit HDBScan for stw/ 648 data points
# Fit HDBScan for stx/ 169 data points
# Fit HDBScan for sv8/ 3367 data points
# generated 2 port counts for geohash sv8
# Fit HDBScan for svb/ 1561 data points
# generated 2 port counts for geohash svb
# Fit HDBScan for sx4/ 400 data points
# generated 2 port counts for geohash sx4
# Fit HDBScan for sx5/ 1498 data points
# generated 2 port counts for geohash sx5
# Fit HDBScan for sxk/ 668 data points
# generated 2 port counts for geohash sxk
# Fit HDBScan for sxq/ 1943 data points
# generated 2 port counts for geohash sxq
# Fit HDBScan for sxu/ 324 data points
# Fit HDBScan for sy9/ 2145 data points
# generated 2 port counts for geohash sy9
# Fit HDBScan for szf/ 476 data points
# generated 2 port counts for geohash szf
# Fit HDBScan for szg/ 835 data points
# generated 2 port counts for geohash szg
# Fit HDBScan for t73/ 112 data points
# Fit HDBScan for tds/ 1006 data points
# generated 2 port counts for geohash tds
# Fit HDBScan for te5/ 286 data points
# Fit HDBScan for teb/ 356 data points
# Fit HDBScan for tec/ 116 data points
# Fit HDBScan for tee/ 399 data points
# generated 2 port counts for geohash tee
# Fit HDBScan for teg/ 199 data points
# Fit HDBScan for teh/ 616 data points
# generated 2 port counts for geohash teh
# Fit HDBScan for tf8/ 2248 data points
# generated 2 port counts for geohash tf8
# Fit HDBScan for tf9/ 1468 data points
# generated 2 port counts for geohash tf9
# Fit HDBScan for tg5/ 1436 data points
# generated 2 port counts for geohash tg5
# Fit HDBScan for tgt/ 2204 data points
# generated 2 port counts for geohash tgt
# Fit HDBScan for tgw/ 180 data points
# Fit HDBScan for thg/ 1194 data points
# generated 3 port counts for geohash thg
# Fit HDBScan for thk/ 630 data points
# Fit HDBScan for thq/ 1331 data points
# generated 2 port counts for geohash thq
# Fit HDBScan for ths/ 503 data points
# generated 2 port counts for geohash ths
# Fit HDBScan for tht/ 352 data points
# Fit HDBScan for thu/ 1065 data points
# generated 2 port counts for geohash thu
# Fit HDBScan for thx/ 170 data points
# Fit HDBScan for tk2/ 2587 data points
# generated 2 port counts for geohash tk2
# Fit HDBScan for tk8/ 176 data points
# Fit HDBScan for ts1/ 11810 data points
# generated 3 port counts for geohash ts1
# Fit HDBScan for u0b/ 148 data points
# Fit HDBScan for u11/ 1613 data points
# generated 2 port counts for geohash u11
# Fit HDBScan for u13/ 746 data points
# generated 2 port counts for geohash u13
# Fit HDBScan for u14/ 12017 data points
# generated 3 port counts for geohash u14
# Fit HDBScan for u15/ 166 data points
# Fit HDBScan for u16/ 1606 data points
# generated 2 port counts for geohash u16
# Fit HDBScan for u17/ 2129 data points
# generated 2 port counts for geohash u17
# Fit HDBScan for u18/ 1470 data points
# generated 2 port counts for geohash u18
# Fit HDBScan for u1t/ 712 data points
# generated 2 port counts for geohash u1t
# Fit HDBScan for u1x/ 467 data points
# generated 2 port counts for geohash u1x
# Fit HDBScan for u1y/ 317 data points
# Fit HDBScan for u21/ 529 data points
# Fit HDBScan for u3t/ 160 data points
# Fit HDBScan for u8j/ 152 data points
# Fit HDBScan for u8n/ 2463 data points
# generated 2 port counts for geohash u8n
# Fit HDBScan for u8q/ 6567 data points
# generated 2 port counts for geohash u8q
# Fit HDBScan for ub1/ 160 data points
# Fit HDBScan for ukh/ 2618 data points
# generated 2 port counts for geohash ukh
# Fit HDBScan for w0x/ 4144 data points
# generated 2 port counts for geohash w0x
# Fit HDBScan for w21/ 5682 data points
# generated 2 port counts for geohash w21
# Fit HDBScan for w22/ 952 data points
# generated 2 port counts for geohash w22
# Fit HDBScan for w24/ 2776 data points
# generated 3 port counts for geohash w24
# Fit HDBScan for w26/ 5954 data points
# generated 2 port counts for geohash w26
# Fit HDBScan for w4p/ 287 data points
# Fit HDBScan for w7s/ 165 data points
# Fit HDBScan for w7u/ 111 data points
# Fit HDBScan for w7v/ 15826 data points
# generated 2 port counts for geohash w7v
# Fit HDBScan for w7w/ 10325 data points
# generated 2 port counts for geohash w7w
# Fit HDBScan for w7x/ 127 data points
# Fit HDBScan for w7y/ 4828 data points
# generated 2 port counts for geohash w7y
# Fit HDBScan for w85/ 5144 data points
# generated 2 port counts for geohash w85
# Fit HDBScan for w8c/ 427 data points
# Fit HDBScan for w8e/ 1631 data points
# Fit HDBScan for w8f/ 597 data points
# generated 2 port counts for geohash w8f
# Fit HDBScan for w8k/ 496 data points
# Fit HDBScan for wc1/ 196 data points
# Fit HDBScan for wc8/ 3363 data points
# generated 2 port counts for geohash wc8
# Fit HDBScan for wdt/ 5135 data points
# generated 2 port counts for geohash wdt
# Fit HDBScan for web/ 2653 data points
# generated 3 port counts for geohash web
# Fit HDBScan for wec/ 5699 data points
# generated 2 port counts for geohash wec
# Fit HDBScan for wev/ 750 data points
# generated 2 port counts for geohash wev
# Fit HDBScan for ws0/ 2313 data points
# generated 3 port counts for geohash ws0
# Fit HDBScan for ws7/ 522 data points
# Fit HDBScan for wsj/ 5049 data points
# generated 2 port counts for geohash wsj
# Fit HDBScan for wsk/ 2279 data points
# generated 2 port counts for geohash wsk
# Fit HDBScan for wsm/ 2592 data points
# generated 2 port counts for geohash wsm
# Fit HDBScan for wst/ 6021 data points
# generated 2 port counts for geohash wst
# Fit HDBScan for wsy/ 528 data points
# Fit HDBScan for wtp/ 224 data points
# Fit HDBScan for wtq/ 17500 data points
# generated 4 port counts for geohash wtq
# Fit HDBScan for wtr/ 23475 data points
# generated 5 port counts for geohash wtr
# Fit HDBScan for wtt/ 8633 data points
# generated 2 port counts for geohash wtt
# Fit HDBScan for wtw/ 11012 data points
# generated 2 port counts for geohash wtw
# Fit HDBScan for wtx/ 47875 data points
# generated 3 port counts for geohash wtx
# Fit HDBScan for wty/ 415 data points
# generated 2 port counts for geohash wty
# Fit HDBScan for wvj/ 121 data points
# Fit HDBScan for wvq/ 189 data points
# Fit HDBScan for wvt/ 150 data points
# Fit HDBScan for wvu/ 873 data points
# generated 2 port counts for geohash wvu
# Fit HDBScan for wvv/ 2491 data points
# generated 2 port counts for geohash wvv
# Fit HDBScan for wvw/ 358 data points
# Fit HDBScan for wvx/ 488 data points
# Fit HDBScan for wvy/ 101 data points
# Fit HDBScan for wvz/ 349 data points
# Fit HDBScan for wwg/ 6442 data points
# generated 2 port counts for geohash wwg
# Fit HDBScan for wwh/ 6480 data points
# generated 2 port counts for geohash wwh
# Fit HDBScan for wwj/ 9994 data points
# generated 2 port counts for geohash wwj
# Fit HDBScan for wwm/ 46366 data points
# generated 4 port counts for geohash wwm
# Fit HDBScan for wwq/ 4054 data points
# generated 2 port counts for geohash wwq
# Fit HDBScan for wwt/ 788 data points
# generated 2 port counts for geohash wwt
# Fit HDBScan for wwu/ 86092 data points
# generated 2 port counts for geohash wwu
# Fit HDBScan for wwv/ 374 data points
# Fit HDBScan for www/ 3816 data points
# generated 3 port counts for geohash www
# Fit HDBScan for wwx/ 156 data points
# Fit HDBScan for wwy/ 3626 data points
# generated 3 port counts for geohash wwy
# Fit HDBScan for wxj/ 3787 data points
# generated 2 port counts for geohash wxj
# Fit HDBScan for wxn/ 19711 data points
# generated 4 port counts for geohash wxn
# Fit HDBScan for wy1/ 501 data points
# generated 2 port counts for geohash wy1
# Fit HDBScan for wy3/ 694 data points
# generated 2 port counts for geohash wy3
# Fit HDBScan for wy4/ 7266 data points
# generated 2 port counts for geohash wy4
# Fit HDBScan for wy5/ 6171 data points
# generated 5 port counts for geohash wy5
# Fit HDBScan for wy9/ 11610 data points
# generated 3 port counts for geohash wy9
# Fit HDBScan for wyd/ 2791 data points
# generated 2 port counts for geohash wyd
# Fit HDBScan for wyj/ 2012 data points
# generated 2 port counts for geohash wyj
# Fit HDBScan for wyk/ 5492 data points
# generated 2 port counts for geohash wyk
# Fit HDBScan for wyn/ 6737 data points
# generated 4 port counts for geohash wyn
# Fit HDBScan for wyp/ 4761 data points
# generated 4 port counts for geohash wyp
# Fit HDBScan for wz0/ 2496 data points
# generated 2 port counts for geohash wz0
# Fit HDBScan for wzt/ 343 data points
# Fit HDBScan for wzw/ 732 data points
# generated 2 port counts for geohash wzw
# Fit HDBScan for xj8/ 402 data points
# Fit HDBScan for xj9/ 163 data points
# Fit HDBScan for xjb/ 325 data points
# Fit HDBScan for xjc/ 358 data points
# Fit HDBScan for xjf/ 142 data points
# Fit HDBScan for xjg/ 188 data points
# Fit HDBScan for xju/ 114 data points
# Fit HDBScan for xn0/ 1912 data points
# generated 3 port counts for geohash xn0
# Fit HDBScan for xn1/ 2962 data points
# generated 2 port counts for geohash xn1
# Fit HDBScan for xn5/ 389 data points
# Fit HDBScan for xn7/ 6533 data points
# generated 2 port counts for geohash xn7
# Fit HDBScan for xnk/ 4172 data points
# generated 2 port counts for geohash xnk
# Fit HDBScan for xnu/ 123 data points
# Fit HDBScan for xps/ 664 data points
# generated 2 port counts for geohash xps
# Fit HDBScan for z0e/ 898 data points
# Fit HDBScan for z0s/ 105 data points
