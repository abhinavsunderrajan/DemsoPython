# %%
import tensorflow as tf
import numpy as np
np.random.seed(42)
import matplotlib.pyplot as plt
tf.set_random_seed(42)
# %matplotlib notebook

# %%
n_input=2
n_dense=4

# %%
x=tf.placeholder(tf.float32,shape=[None,n_input])
w=tf.Variable(tf.random_normal([n_input,n_dense]))
b=tf.Variable(tf.zeros(n_dense))

# %%
#simple sigmoid functions
z=tf.add(tf.matmul(x,w),b)
a=tf.sigmoid(z)

# %%
#initialze the variables
initializer_operation=tf.global_variables_initializer()
with tf.Session() as session:
    session.run(initializer_operation)
    layer_output=session.run(a,feed_dict={x:np.random.random([1,n_input])})

# %%
plt.hist(np.transpose(layer_output))
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (array([58.,  2.,  6.,  1.,  1.,  1.,  3.,  3.,  3., 50.]),
#  array([3.82453852e-16, 1.00000000e-01, 2.00000000e-01, 3.00000000e-01,
#         4.00000000e-01, 5.00000000e-01, 6.00000000e-01, 7.00000000e-01,
#         8.00000000e-01, 9.00000000e-01, 1.00000000e+00]),
#  <a list of 10 Patch objects>)

# %%
x=np.array([[2,2],[3,3]])
y=np.array([1,1])
print(x,y)
print(x+y)
# Out:
# (2, 2) (2,)
# [[3 3]
#  [4 4]]
