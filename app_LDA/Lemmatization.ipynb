# %%
import pandas as pd
import pymysql
import matplotlib.style as style
import matplotlib.pyplot as plt
import datetime
from datetime import timedelta
import neon_cred as neon
import pymysql
import seaborn as sns
import numpy as np
style.use('ggplot')
from IPython.display import display, HTML
import matplotlib.cm as cm
import os
from joblib import Parallel, delayed
import re
from tqdm import tqdm
# %matplotlib inline
import time

# Gensim
import gensim
import nltk; nltk.download('stopwords'); nltk.download('words')
from nltk.corpus import stopwords
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import all_stops as stops

# spacy for lemmatization
import spacy
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/PocketmathUser/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/PocketmathUser/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# ## Get the scraped data

# %%
bundle_desc =pd.read_csv("bundle_desc.csv")

# %% [markdown]
# ## Preprocessing
# 1. Regex based trimming
# 2. Stop word removal
# 3. Make bigrams and trigrams
# 4. lemmatization

# %%
# stop_words = stopwords.words('english')
# stop_words.extend(['from', 'use'])
stop_words = stops.extended_stop_words
stop_words.extend(["free", "android", "privacy_policy", "add", "device", "feature",
                   "phone", "good", "application", "mobile", "app", "set", "features",
                   "win", "choose", "yan", "user", "dan", "version", "san", "day",
                   "subscription", "subscribe", "para","yang"])

words = set(nltk.corpus.words.words())


# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
# Do lemmatization keeping only noun, adj, vb, adv
# https://spacy.io/api/annotation


nlp = spacy.load('/anaconda3/lib/python3.7/site-packages/en_core_web_sm/en_core_web_sm-2.0.0', disable=['parser', 'ner'])
allowed_postags = ['NOUN', 'ADJ', 'VERB', 'ADV']

# %%
def some_regex(x):
    x = re.sub('\S*@\S*\s?', '', x)
    x = re.sub('\s+', ' ', x)
    x = re.sub("\'", "", x)
    return x

# %%
bundle_desc["description"] = bundle_desc["description"].apply(some_regex)

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_non_english_words(texts):
    return [[word for word in doc if (word in words)] for doc in texts]


def remove_stop_words(texts):
    return [[word for word in doc \
             if (word not in stop_words) and (len(word) > 2)] for doc in texts]


def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]


def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(desc):
    doc = nlp(" ".join(desc))
    doc_list = [token.lemma_ for token in doc if (token.pos_ in allowed_postags) and \
               (token.lemma_ in words)]
    return doc_list

# %%
data_words = []
descriptions_list = list(bundle_desc["description"])
for desc in descriptions_list:
    # deacc=True removes punctuations
    data_words.append(gensim.utils.simple_preprocess(str(desc),
                                                     deacc=True))

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100)
# higher threshold fewer phrases.

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)

# %%
start = time.time()
data_words_lemmatized = [lemmatization(desc) for desc in data_words]
end = time.time()
print((end-start), "seconds")
# Out:
# 1085.7185957431793 seconds

# %%
# Form Bigrams
data_words_bigrams = make_bigrams(data_words_lemmatized)

# Remove Stop Words
data_words_nostops = remove_stop_words(data_words_bigrams)

# %%
from collections import Counter
word_list = [word for doc in data_words_nostops for word in doc]
x = Counter(word_list)
x.most_common()
# Out:
# [('game', 249221),
#  ('play', 89783),
#  ('photo', 58244),
#  ('time', 56313),
#  ('car', 54438),
#  ('find', 49092),
#  ('fun', 42995),
#  ('level', 39975),
#  ('video', 38286),
#  ('object', 38264),
#  ('real', 38038),
#  ('friend', 35706),
#  ('easy', 35517),
#  ('news', 33966),
#  ('city', 33442),
#  ('drive', 32560),
#  ('enjoy', 31879),
#  ('love', 30687),
#  ('share', 29408),
#  ('simulator', 27254),
#  ('picture', 25895),
#  ('live', 25421),
#  ('search', 25364),
#  ('screen', 24828),
#  ('wallpaper', 24542),
#  ('image', 24409),
#  ('puzzle', 24267),
#  ('color', 24145),
#  ('favorite', 23576),
#  ('theme', 23453),
#  ('mode', 23236),
#  ('support', 22617),
#  ('control', 22546),
#  ('design', 22481),
#  ('music', 22351),
#  ('experience', 22342),
#  ('create', 21919),
#  ('beautiful', 21810),
#  ('word', 21792),
#  ('player', 21757),
#  ('radio', 21712),
#  ('include', 21531),
#  ('challenge', 21528),
#  ('save', 21251),
#  ('amazing', 20695),
#  ('simple', 20601),
#  ('truck', 20429),
#  ('sound', 19920),
#  ('super', 19708),
#  ('skill', 19513),
#  ('work', 19306),
#  ('fast', 19237),
#  ('start', 19202),
#  ('hero', 18451),
#  ('learn', 18388),
#  ('race', 18169),
#  ('song', 18080),
#  ('hide', 17766),
#  ('life', 17644),
#  ('high', 17349),
#  ('speed', 17323),
#  ('follow', 17182),
#  ('hidden', 16957),
#  ('mission', 16842),
#  ('great', 16582),
#  ('graphic', 16339),
#  ('people', 16096),
#  ('provide', 16074),
#  ('late', 16066),
#  ('card', 16026),
#  ('animal', 16005),
#  ('select', 15751),
#  ('full', 15713),
#  ('tap', 15691),
#  ('number', 15641),
#  ('twitter', 15558),
#  ('track', 15526),
#  ('update', 15522),
#  ('robot', 15399),
#  ('frame', 14995),
#  ('parking', 14934),
#  ('complete', 14880),
#  ('top', 14871),
#  ('keyboard', 14841),
#  ('change', 14655),
#  ('story', 14637),
#  ('social', 14632),
#  ('list', 14511),
#  ('contact', 14491),
#  ('racing', 14480),
#  ('road', 14290),
#  ('realistic', 14251),
#  ('text', 14161),
#  ('adventure', 14151),
#  ('background', 14065),
#  ('match', 13973),
#  ('power', 13908),
#  ('bike', 13640),
#  ('call', 13600),
#  ('view', 13486),
#  ('message', 13450),
#  ('fight', 13398),
#  ('access', 13390),
#  ('shoot', 13380),
#  ('ready', 13363),
#  ('score', 13356),
#  ('battle', 13271),
#  ('stunt', 12953),
#  ('girl', 12816),
#  ('map', 12804),
#  ('click', 12429),
#  ('style', 12423),
#  ('unique', 12412),
#  ('sport', 12392),
#  ('police', 12362),
#  ('weather', 12351),
#  ('lot', 12312),
#  ('action', 12302),
#  ('move', 12238),
#  ('check', 12212),
#  ('driving', 12064),
#  ('place', 11939),
#  ('button', 11911),
#  ('family', 11718),
#  ('watch', 11635),
#  ('read', 11620),
#  ('option', 11500),
#  ('test', 11495),
#  ('camera', 11447),
#  ('feel', 11436),
#  ('bus', 11411),
#  ('note', 11397),
#  ('store', 11344),
#  ('station', 11288),
#  ('big', 11279),
#  ('fly', 11248),
#  ('content', 11219),
#  ('listen', 11217),
#  ('monster', 11154),
#  ('send', 11075),
#  ('service', 11017),
#  ('turn', 11015),
#  ('point', 11004),
#  ('touch', 10995),
#  ('enemy', 10907),
#  ('special', 10834),
#  ('dress', 10829),
#  ('location', 10811),
#  ('child', 10803),
#  ('offer', 10691),
#  ('collect', 10687),
#  ('driver', 10687),
#  ('type', 10669),
#  ('purchase', 10608),
#  ('base', 10604),
#  ('cool', 10552),
#  ('baby', 10529),
#  ('question', 10493),
#  ('multiple', 10455),
#  ('open', 10355),
#  ('perfect', 10288),
#  ('collection', 10263),
#  ('unlock', 10186),
#  ('war', 10158),
#  ('environment', 10123),
#  ('train', 10113),
#  ('easily', 10029),
#  ('earn', 9943),
#  ('network', 9712),
#  ('daily', 9676),
#  ('awesome', 9669),
#  ('thing', 9621),
#  ('team', 9576),
#  ('item', 9571),
#  ('setting', 9492),
#  ('build', 9479),
#  ('medium', 9470),
#  ('star', 9265),
#  ('language', 9193),
#  ('bring', 9189),
#  ('editor', 9182),
#  ('face', 9179),
#  ('crazy', 9135),
#  ('require', 9123),
#  ('status', 8975),
#  ('tool', 8941),
#  ('visit', 8930),
#  ('money', 8847),
#  ('popular', 8845),
#  ('army', 8818),
#  ('file', 8775),
#  ('funny', 8744),
#  ('traffic', 8677),
#  ('wait', 8673),
#  ('vehicle', 8634),
#  ('character', 8631),
#  ('exciting', 8563),
#  ('attack', 8479),
#  ('escape', 8449),
#  ('lock', 8430),
#  ('year', 8420),
#  ('hour', 8408),
#  ('superhero', 8391),
#  ('chat', 8371),
#  ('book', 8368),
#  ('connection', 8343),
#  ('transport', 8333),
#  ('tablet', 8287),
#  ('improve', 8211),
#  ('clean', 8153),
#  ('fan', 8136),
#  ('food', 8069),
#  ('install', 8032),
#  ('local', 8028),
#  ('datum', 8014),
#  ('sticker', 7951),
#  ('classic', 7950),
#  ('pick', 7831),
#  ('block', 7786),
#  ('bubble', 7750),
#  ('coin', 7723),
#  ('jump', 7713),
#  ('cute', 7676),
#  ('join', 7650),
#  ('man', 7626),
#  ('master', 7542),
#  ('hard', 7480),
#  ('notification', 7478),
#  ('audio', 7463),
#  ('ultimate', 7456),
#  ('system', 7431),
#  ('history', 7427),
#  ('weapon', 7388),
#  ('ball', 7330),
#  ('account', 7325),
#  ('hit', 7308),
#  ('break', 7279),
#  ('gallery', 7276),
#  ('leave', 7240),
#  ('powerful', 7159),
#  ('extreme', 7153),
#  ('school', 7121),
#  ('simulation', 7073),
#  ('feedback', 7027),
#  ('modern', 7025),
#  ('product', 7007),
#  ('category', 6935),
#  ('step', 6931),
#  ('water', 6927),
#  ('gun', 6921),
#  ('discover', 6899),
#  ('guide', 6896),
#  ('site', 6887),
#  ('long', 6885),
#  ('kill', 6883),
#  ('survival', 6836),
#  ('main', 6792),
#  ('task', 6772),
#  ('hand', 6768),
#  ('connect', 6758),
#  ('size', 6722),
#  ('apply', 6716),
#  ('choice', 6689),
#  ('light', 6684),
#  ('detail', 6624),
#  ('country', 6580),
#  ('today', 6575),
#  ('interesting', 6567),
#  ('night', 6518),
#  ('animation', 6502),
#  ('memory', 6454),
#  ('interface', 6439),
#  ('term', 6401),
#  ('area', 6368),
#  ('edit', 6364),
#  ('article', 6344),
#  ('order', 6295),
#  ('fighting', 6288),
#  ('clear', 6285),
#  ('explore', 6267),
#  ('sniper', 6251),
#  ('event', 6242),
#  ('quick', 6210),
#  ('smart', 6193),
#  ('current', 6191),
#  ('rescue', 6173),
#  ('result', 6158),
#  ('dog', 6128),
#  ('solve', 6122),
#  ('group', 6104),
#  ('channel', 6098),
#  ('smooth', 6087),
#  ('problem', 6082),
#  ('single', 6080),
#  ('suggestion', 6072),
#  ('display', 6069),
#  ('post', 6050),
#  ('street', 6029),
#  ('age', 6019),
#  ('happy', 5971),
#  ('care', 5965),
#  ('skin', 5931),
#  ('cat', 5927),
#  ('movie', 5925),
#  ('house', 5897),
#  ('alert', 5895),
#  ('dictionary', 5891),
#  ('key', 5887),
#  ('record', 5887),
#  ('party', 5875),
#  ('shooting', 5874),
#  ('fire', 5859),
#  ('fashion', 5856),
#  ('colorful', 5787),
#  ('job', 5778),
#  ('rate', 5776),
#  ('voice', 5767),
#  ('upgrade', 5762),
#  ('ability', 5757),
#  ('pro', 5736),
#  ('avoid', 5732),
#  ('icon', 5724),
#  ('quote', 5700),
#  ('official', 5695),
#  ('press', 5674),
#  ('auto', 5656),
#  ('suit', 5645),
#  ('pack', 5623),
#  ('mind', 5614),
#  ('maker', 5586),
#  ('buy', 5581),
#  ('charge', 5521),
#  ('write', 5521),
#  ('reach', 5497),
#  ('recipe', 5487),
#  ('perform', 5479),
#  ('large', 5477),
#  ('eye', 5471),
#  ('cargo', 5471),
#  ('high_quality', 5456),
#  ('impossible', 5427),
#  ('room', 5407),
#  ('mountain', 5399),
#  ('review', 5395),
#  ('football', 5391),
#  ('increase', 5390),
#  ('zombie', 5383),
#  ('kind', 5365),
#  ('comment', 5349),
#  ('develop', 5341),
#  ('enter', 5317),
#  ('hot', 5312),
#  ('wild', 5292),
#  ('spot', 5281),
#  ('quality', 5279),
#  ('privacy', 5274),
#  ('hair', 5245),
#  ('air', 5219),
#  ('manage', 5218),
#  ('brand', 5190),
#  ('crime', 5145),
#  ('ride', 5139),
#  ('princess', 5137),
#  ('font', 5130),
#  ('hunt', 5125),
#  ('beat', 5124),
#  ('space', 5088),
#  ('remove', 5070),
#  ('small', 5065),
#  ('chance', 5056),
#  ('finger', 5029),
#  ('draw', 5020),
#  ('automatically', 5005),
#  ('board', 4996),
#  ('variety', 4979),
#  ('solitaire', 4978),
#  ('answer', 4972),
#  ('feed', 4970),
#  ('body', 4964),
#  ('art', 4961),
#  ('pop', 4950),
#  ('dream', 4921),
#  ('fill', 4920),
#  ('gangster', 4919),
#  ('horse', 4916),
#  ('idea', 4912),
#  ('shooter', 4911),
#  ('business', 4905),
#  ('heavy', 4903),
#  ('unlimited', 4869),
#  ('rule', 4867),
#  ('physics', 4853),
#  ('program', 4852),
#  ('heart', 4840),
#  ('secret', 4833),
#  ('stay', 4827),
#  ('limit', 4784),
#  ('machine', 4778),
#  ('receive', 4775),
#  ('criminal', 4768),
#  ('goal', 4767),
#  ('function', 4765),
#  ('mail', 4756),
#  ('web', 4752),
#  ('plan', 4751),
#  ('filter', 4736),
#  ('travel', 4724),
#  ('completely', 4719),
#  ('spider', 4717),
#  ('battery', 4699),
#  ('obstacle', 4685),
#  ('bonus', 4676),
#  ('link', 4674),
#  ('lead', 4668),
#  ('endless', 4665),
#  ('professional', 4642),
#  ('directly', 4619),
#  ('park', 4618),
#  ('incredible', 4609),
#  ('drop', 4561),
#  ('decorate', 4538),
#  ('menu', 4536),
#  ('meet', 4495),
#  ('letter', 4451),
#  ('flower', 4432),
#  ('huge', 4424),
#  ('swipe', 4423),
#  ('browse', 4411),
#  ('pic', 4409),
#  ('talk', 4398),
#  ('future', 4397),
#  ('difference', 4395),
#  ('forget', 4394),
#  ('bird', 4387),
#  ('quiz', 4383),
#  ('reward', 4382),
#  ('stunning', 4382),
#  ('candy', 4372),
#  ('brain', 4372),
#  ('magic', 4371),
#  ('boy', 4345),
#  ('dangerous', 4342),
#  ('target', 4335),
#  ('ton', 4333),
#  ('woman', 4329),
#  ('construction', 4297),
#  ('personal', 4268),
#  ('hear', 4249),
#  ('sweet', 4234),
#  ('protect', 4233),
#  ('simply', 4227),
#  ('prepare', 4222),
#  ('pet', 4218),
#  ('destroy', 4203),
#  ('opponent', 4196),
#  ('form', 4193),
#  ('extra', 4178),
#  ('con', 4177),
#  ('gift', 4164),
#  ('fruit', 4162),
#  ('beauty', 4154),
#  ('boost', 4113),
#  ('lover', 4113),
#  ('zoom', 4106),
#  ('state', 4105),
#  ('interactive', 4097),
#  ('chase', 4097),
#  ('person', 4094),
#  ('drift', 4084),
#  ('guess', 4076),
#  ('virtual', 4056),
#  ('pay', 4055),
#  ('force', 4036),
#  ('enable', 4030),
#  ('practice', 4021),
#  ('pass', 4021),
#  ('model', 4020),
#  ('shape', 4018),
#  ('lose', 4011),
#  ('catch', 4007),
#  ('famous', 4004),
#  ('community', 4003),
#  ('head', 4000),
#  ('jungle', 3981),
#  ('safe', 3981),
#  ('health', 3974),
#  ('joke', 3972),
#  ('trick', 3970),
#  ('cover', 3952),
#  ('training', 3923),
#  ('hint', 3922),
#  ('series', 3920),
#  ('true', 3919),
#  ('difficulty', 3908),
#  ('month', 3891),
#  ('fall', 3880),
#  ('drag', 3876),
#  ('minute', 3849),
#  ('futuristic', 3836),
#  ('load', 3834),
#  ('engine', 3830),
#  ('grow', 3809),
#  ('original', 3805),
#  ('difficult', 3796),
#  ('activity', 3793),
#  ('market', 3782),
#  ('helicopter', 3775),
#  ('advertising', 3769),
#  ('entertainment', 3765),
#  ('price', 3753),
#  ('stream', 3741),
#  ('deliver', 3736),
#  ('survive', 3732),
#  ('wonderful', 3729),
#  ('source', 3720),
#  ('transform', 3717),
#  ('browser', 3716),
#  ('king', 3709),
#  ('bank', 3661),
#  ('seek', 3641),
#  ('shop', 3609),
#  ('farm', 3605),
#  ('flash', 3602),
#  ('thrill', 3593),
#  ('league', 3587),
#  ('side', 3579),
#  ('aim', 3565),
#  ('educational', 3554),
#  ('nice', 3554),
#  ('prank', 3541),
#  ('messenger', 3537),
#  ('black', 3526),
#  ('compete', 3509),
#  ('rating', 3485),
#  ('combat', 3484),
#  ('moment', 3476),
#  ('intuitive', 3463),
#  ('crash', 3453),
#  ('fantastic', 3449),
#  ('schedule', 3442),
#  ('carefully', 3441),
#  ('expert', 3441),
#  ('tile', 3439),
#  ('week', 3437),
#  ('collage', 3431),
#  ('land', 3420),
#  ('platform', 3412),
#  ('craft', 3412),
#  ('cut', 3406),
#  ('sky', 3399),
#  ('racer', 3396),
#  ('red', 3389),
#  ('hope', 3389),
#  ('workout', 3377),
#  ('mix', 3368),
#  ('gif', 3357),
#  ('alarm', 3356),
#  ('security', 3354),
#  ('stage', 3351),
#  ('pattern', 3343),
#  ('building', 3342),
#  ('customer', 3334),
#  ('salon', 3331),
#  ('flight', 3331),
#  ('galaxy', 3331),
#  ('remember', 3328),
#  ('hill', 3328),
#  ('condition', 3317),
#  ('custom', 3312),
#  ('company', 3308),
#  ('code', 3304),
#  ('journey', 3301),
#  ('sea', 3285),
#  ('dinosaur', 3282),
#  ('plane', 3268),
#  ('romantic', 3261),
#  ('property', 3256),
#  ('epic', 3255),
#  ('white', 3254),
#  ('tractor', 3246),
#  ('low', 3243),
#  ('developer', 3233),
#  ('fighter', 3232),
#  ('warrior', 3228),
#  ('doctor', 3219),
#  ('adult', 3203),
#  ('dragon', 3197),
#  ('taxi', 3197),
#  ('calendar', 3195),
#  ('highway', 3192),
#  ('nature', 3187),
#  ('box', 3186),
#  ('parent', 3185),
#  ('jeep', 3183),
#  ('bear', 3180),
#  ('destination', 3179),
#  ('permission', 3172),
#  ('god', 3171),
#  ('achievement', 3169),
#  ('continue', 3162),
#  ('direction', 3157),
#  ('transporter', 3149),
#  ('evil', 3145),
#  ('commando', 3140),
#  ('member', 3134),
#  ('short', 3133),
#  ('town', 3130),
#  ('disclaimer', 3118),
#  ('strategy', 3116),
#  ('technology', 3113),
#  ('piece', 3102),
#  ('push', 3088),
#  ('relax', 3084),
#  ('snow', 3081),
#  ('advanced', 3074),
#  ('wheel', 3071),
#  ('national', 3062),
#  ('yang', 3056),
#  ('adjust', 3038),
#  ('cake', 3031),
#  ('outfit', 3031),
#  ('tank', 3021),
#  ('rider', 3012),
#  ('hold', 3007),
#  ('rival', 3002),
#  ('prove', 2998),
#  ('grand', 2989),
#  ('forest', 2989),
#  ('creative', 2979),
#  ('eat', 2976),
#  ('progress', 2974),
#  ('paint', 2973),
#  ('wake', 2967),
#  ('focus', 2965),
#  ('legend', 2965),
#  ('exercise', 2962),
#  ('position', 2961),
#  ('resolution', 2960),
#  ('total', 2959),
#  ('rock', 2955),
#  ('close', 2952),
#  ('format', 2946),
#  ('performance', 2941),
#  ('release', 2931),
#  ('duty', 2931),
#  ('cash', 2925),
#  ('island', 2921),
#  ('wedding', 2918),
#  ('exclusive', 2914),
#  ('champion', 2913),
#  ('human', 2911),
#  ('toy', 2904),
#  ('fully', 2902),
#  ('center', 2890),
#  ('profile', 2882),
#  ('clothe', 2877),
#  ('fish', 2869),
#  ('recommend', 2860),
#  ('combination', 2858),
#  ('sleep', 2857),
#  ('lovely', 2850),
#  ('military', 2847),
#  ('album', 2846),
#  ('optimize', 2846),
#  ('rush', 2843),
#  ('strike', 2837),
#  ('computer', 2835),
#  ('report', 2828),
#  ('totally', 2828),
#  ('combine', 2827),
#  ('launcher', 2812),
#  ('artist', 2811),
#  ('finish', 2810),
#  ('deal', 2810),
#  ('phrase', 2809),
#  ('booster', 2807),
#  ('case', 2800),
#  ('strong', 2797),
#  ('thrilling', 2792),
#  ('delete', 2791),
#  ('opportunity', 2788),
#  ('stylish', 2779),
#  ('issue', 2778),
#  ('stick', 2770),
#  ('detailed', 2760),
#  ('knowledge', 2758),
#  ('dark', 2749),
#  ('blue', 2739),
#  ('fit', 2734),
#  ('soccer', 2718),
#  ('highlight', 2714),
#  ('beach', 2710),
#  ('switch', 2707),
#  ('slide', 2706),
#  ('smash', 2705),
#  ('gold', 2705),
#  ('club', 2704),
#  ('additional', 2694),
#  ('basic', 2689),
#  ('passenger', 2687),
#  ('rid', 2686),
#  ('field', 2685),
#  ('addition', 2681),
#  ('ring', 2681),
#  ('partner', 2678),
#  ('password', 2668),
#  ('grid', 2653),
#  ('crop', 2638),
#  ('spa', 2632),
#  ('faster', 2629),
#  ('route', 2627),
#  ('caller', 2627),
#  ('topic', 2626),
#  ('scene', 2622),
#  ('mania', 2620),
#  ('green', 2617),
#  ('selection', 2616),
#  ('arcade', 2614),
#  ('deadly', 2614),
#  ('table', 2611),
#  ('accord', 2599),
#  ('achieve', 2596),
#  ('student', 2586),
#  ('serve', 2583),
#  ('range', 2573),
#  ('purpose', 2572),
#  ('birthday', 2567),
#  ('dance', 2566),
#  ('defeat', 2559),
#  ('cook', 2555),
#  ('bar', 2555),
#  ('happen', 2553),
#  ('study', 2545),
#  ('spend', 2531),
#  ('worry', 2526),
#  ('capture', 2526),
#  ('premium', 2526),
#  ('personalize', 2521),
#  ('accurate', 2501),
#  ('instant', 2497),
#  ('navigation', 2487),
#  ('secure', 2470),
#  ('international', 2469),
#  ('forecast', 2468),
#  ('cooking', 2467),
#  ('enhance', 2458),
#  ('exam', 2458),
#  ('holiday', 2457),
#  ('path', 2457),
#  ('highly', 2449),
#  ('death', 2447),
#  ('decide', 2443),
#  ('digital', 2441),
#  ('net', 2435),
#  ('random', 2428),
#  ('private', 2423),
#  ('treat', 2421),
#  ('chain', 2413),
#  ('roll', 2407),
#  ('translation', 2407),
#  ('accessory', 2406),
#  ('delicious', 2404),
#  ('entire', 2400),
#  ('manager', 2397),
#  ('depend', 2391),
#  ('public', 2391),
#  ('wi_fi', 2389),
#  ('rotate', 2379),
#  ('compare', 2376),
#  ('newspaper', 2368),
#  ('apple', 2367),
#  ('solution', 2364),
#  ('cost', 2360),
#  ('careful', 2356),
#  ('shot', 2356),
#  ('understand', 2356),
#  ('clock', 2354),
#  ('boss', 2348),
#  ('activate', 2348),
#  ('sign', 2345),
#  ('competition', 2345),
#  ('tournament', 2339),
#  ('crush', 2336),
#  ('document', 2335),
#  ('development', 2325),
#  ('cartoon', 2324),
#  ('prize', 2315),
#  ('wear', 2312),
#  ('absolutely', 2308),
#  ('gain', 2303),
#  ('inspire', 2301),
#  ('desire', 2296),
#  ('regard', 2296),
#  ('creation', 2284),
#  ('instruction', 2280),
#  ('specific', 2276),
#  ('trend', 2274),
#  ('owner', 2273),
#  ('weekly', 2270),
#  ('die', 2269),
#  ('paper', 2266),
#  ('management', 2258),
#  ('visual', 2256),
#  ('process', 2254),
#  ('fantasy', 2248),
#  ('global', 2244),
#  ('log', 2243),
#  ('cricket', 2237),
#  ('rich', 2232),
#  ('mas', 2229),
#  ('gaming', 2224),
#  ('young', 2221),
#  ('creature', 2208),
#  ('affiliate', 2205),
#  ('scan', 2199),
#  ('hunting', 2198),
#  ('amount', 2195),
#  ('studio', 2192),
#  ('direct', 2189),
#  ('resource', 2188),
#  ('operation', 2177),
#  ('address', 2173),
#  ('door', 2168),
#  ('contest', 2167),
#  ('speak', 2162),
#  ('animate', 2157),
#  ('blast', 2148),
#  ('airplane', 2148),
#  ('surprise', 2148),
#  ('healthy', 2145),
#  ('lion', 2145),
#  ('double', 2144),
#  ('desert', 2144),
#  ('finding', 2139),
#  ('earth', 2137),
#  ('material', 2133),
#  ('arena', 2132),
#  ('attractive', 2131),
#  ('class', 2129),
#  ('award', 2124),
#  ('cop', 2122),
#  ('notice', 2122),
#  ('bad', 2117),
#  ('common', 2111),
#  ('spin', 2111),
#  ('compatible', 2109),
#  ('pretty', 2109),
#  ('ice', 2105),
#  ('season', 2104),
#  ('motorcycle', 2087),
#  ('restaurant', 2084),
#  ('terrorist', 2077),
#  ('flip', 2076),
#  ('calculator', 2074),
#  ('situation', 2069),
#  ('piano', 2066),
#  ('instantly', 2064),
#  ('shopping', 2057),
#  ('period', 2057),
#  ('pour', 2055),
#  ('boat', 2053),
#  ('timer', 2050),
#  ('express', 2049),
#  ('square', 2044),
#  ('radar', 2044),
#  ('horoscope', 2044),
#  ('wall', 2041),
#  ('tracker', 2039),
#  ('sell', 2038),
#  ('advance', 2032),
#  ('ship', 2027),
#  ('suitable', 2021),
#  ('disable', 2019),
#  ('excellent', 2019),
#  ('fact', 2017),
#  ('matter', 2016),
#  ('tune', 2012),
#  ('natural', 2012),
#  ('rise', 2012),
#  ('interest', 2009),
#  ('launch', 2003),
#  ('request', 2002),
#  ('pizza', 2001),
#  ('payment', 2000),
#  ('energy', 1997),
#  ('relate', 1987),
#  ('title', 1986),
#  ('maximum', 1984),
#  ('walk', 1977),
#  ('fresh', 1975),
#  ('prayer', 1970),
#  ('luxury', 1969),
#  ('teach', 1968),
#  ('cube', 1967),
#  ('soldier', 1966),
#  ('specially', 1962),
#  ('cloud', 1961),
#  ('quest', 1960),
#  ('anda', 1958),
#  ('garden', 1955),
#  ('magical', 1953),
#  ('creator', 1953),
#  ('mark', 1952),
#  ('major', 1944),
#  ('flashlight', 1941),
#  ('german', 1936),
#  ('jewel', 1936),
#  ('agree', 1932),
#  ('rank', 1930),
#  ('correct', 1928),
#  ('layout', 1927),
#  ('trailer', 1926),
#  ('kitchen', 1923),
#  ('angry', 1921),
#  ('ideal', 1915),
#  ('ghost', 1912),
#  ('sort', 1911),
#  ('publish', 1910),
#  ('cup', 1910),
#  ('wolf', 1908),
#  ('server', 1905),
#  ('office', 1905),
#  ('delivery', 1891),
#  ('verse', 1887),
#  ('tree', 1880),
#  ('success', 1876),
#  ('user_friendly', 1876),
#  ('gorgeous', 1871),
#  ('scary', 1871),
#  ('vocabulary', 1866),
#  ('stand', 1864),
#  ('usage', 1863),
#  ('damage', 1861),
#  ('invite', 1860),
#  ('feeling', 1858),
#  ('automatic', 1854),
#  ('cross', 1852),
#  ('count', 1850),
#  ('reading', 1849),
#  ('winter', 1848),
#  ('gear', 1842),
#  ('shadow', 1842),
#  ('input', 1838),
#  ('sad', 1838),
#  ('bomb', 1836),
#  ('throw', 1827),
#  ('library', 1826),
#  ('streaming', 1820),
#  ('bright', 1817),
#  ('decoration', 1815),
#  ('volume', 1815),
#  ('york', 1813),
#  ('convert', 1811),
#  ('arrow', 1808),
#  ('patient', 1806),
#  ('general', 1796),
#  ('tutorial', 1796),
#  ('ticket', 1792),
#  ('element', 1784),
#  ('limited', 1782),
#  ('attention', 1781),
#  ('grab', 1780),
#  ('genre', 1780),
#  ('temperature', 1780),
#  ('edge', 1778),
#  ('ice_cream', 1777),
#  ('airport', 1776),
#  ('broadcast', 1775),
#  ('front', 1774),
#  ('copyright', 1771),
#  ('emergency', 1771),
#  ('handle', 1765),
#  ('guy', 1765),
#  ('deep', 1764),
#  ('killer', 1764),
#  ('shark', 1764),
#  ('friendly', 1754),
#  ('rat', 1749),
#  ('extremely', 1748),
#  ('final', 1744),
#  ('ramp', 1740),
#  ('traditional', 1740),
#  ('castle', 1737),
#  ('law', 1737),
#  ('drink', 1733),
#  ('translate', 1732),
#  ('furious', 1729),
#  ('royal', 1729),
#  ('trip', 1725),
#  ('mood', 1724),
#  ('glass', 1723),
#  ('standard', 1722),
#  ('slow', 1719),
#  ('valentine', 1716),
#  ('register', 1714),
#  ('finally', 1707),
#  ('summer', 1707),
#  ('generate', 1705),
#  ('round', 1703),
#  ('transfer', 1702),
#  ...]

# %%
processed = [" ".join(doc) for doc in data_words_nostops]

# %%
lemmatized_df = pd.DataFrame({"lemmatized_desc": processed})
lemmatized_df["bundle_id"] = bundle_desc["bundle_id"]
lemmatized_df["description"] = bundle_desc["description"]

# %%
lemmatized_df.to_csv("lemmatized_df.csv", index=False)
lemmatized_df.head(10)
# Out:
#                                      lemmatized_desc   bundle_id  \
# 0  block engaging puzzle game simple distinctive ...  1000548274
# 1  hooked fish daily catch experience thrill catc...  1000773093
# 2  cannon hero arrive join rocket boy save evil f...  1000958628
# 3  time flagship news brand medium group bring la...  1000991178
# 4  chance delve construction build stuff game fee...  1001013071
# 5     yon twitter apple tahsil apple alan auto_renew  1001115878
# 6  love blackjack play blackjack game store fuss ...  1001387844
# 7                                                     1001402307
# 8  play drift game store unique car fast furious ...  1001425491
# 9  epic zombie hibernate year ago ground construc...  1001455591
#
#                                          description
# 0  1010 Block is an engaging puzzle game with a s...
# 1  Get hooked with Rapala® Fishing - Daily Catch!...
# 2  THE CANNON HERO HAS ARRIVED. Join Rocket Boy a...
# 3  Hindustan Times, the flagship news brand of th...
# 4  This is your chance to delve into the world of...
# 5  TV8 yan ekran uygulamasıyla yayınlarımıza anın...
# 6  Do you love Blackjack? Play the best FREE Blac...
# 7  本應用包含百家講壇開播至今所有的音頻內容，並且將不斷更新。 ◽《百家講壇》是中央電視臺科教頻...
# 8  Play the #1 drifting game on the App Store wit...
# 9  An Epic Come back of the Zombies hibernating f...
